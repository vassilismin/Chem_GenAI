# %% [markdown]
# <a href="https://colab.research.google.com/github/vassilismin/Chem_GenAI/blob/main/Load_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/vassilismin/Chem_GenAI.git
# Out:
# Cloning into 'Chem_GenAI'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
